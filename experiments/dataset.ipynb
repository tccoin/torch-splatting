# %%
import plotly.graph_objects as go
import numpy as np
import cv2

import sys
sys.path.append('../')
from rkhs_splatting.utils.dataloader import TartanAirLoader, TUMLoader

# %%
dataset = TUMLoader('/home/junzhewu/dataset/junzhe/tum/rgbd_dataset_freiburg1_room')
rgb, depth = dataset.read_current_rgbd()
# plot depth

# %%
depth.max()
# Out:
# 18200

# %%
# load 16bit grayscale image
depth = cv2.imread(
            f'/home/junzhewu/dataset/junzhe/tum/rgbd_dataset_freiburg1_room/depth/{dataset.associations[0][1]}.png', cv2.IMREAD_ANYDEPTH)/5000

# %%
fig = go.Figure(data=go.Heatmap(z=depth, colorscale='gray'))
fig.update_layout(width=640, height=480)
fig.update_layout(yaxis_autorange='reversed')
fig.show()
# Out:
# <div>                            <div id="aa740114-e111-4d4e-854a-de858c838b36" class="plotly-graph-div" style="height:480px; width:640px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa740114-e111-4d4e-854a-de858c838b36")) {                    Plotly.newPlot(                        "aa740114-e111-4d4e-854a-de858c838b36",                        [{"colorscale":[[0.0,"rgb(0, 0, 0)"],[0.09090909090909091,"rgb(16, 16, 16)"],[0.18181818181818182,"rgb(38, 38, 38)"],[0.2727272727272727,"rgb(59, 59, 59)"],[0.36363636363636365,"rgb(81, 80, 80)"],[0.45454545454545453,"rgb(102, 101, 101)"],[0.5454545454545454,"rgb(124, 123, 122)"],[0.6363636363636364,"rgb(146, 146, 145)"],[0.7272727272727273,"rgb(171, 171, 170)"],[0.8181818181818182,"rgb(197, 197, 195)"],[0.9090909090909091,"rgb(224, 224, 223)"],[1.0,"rgb(254, 254
# ...
